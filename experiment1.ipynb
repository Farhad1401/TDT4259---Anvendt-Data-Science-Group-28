# %% [markdown]
# # Experiment 1 #
# With consumption last week vs without

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pycaret
from plotly.offline import iplot
import plotly.graph_objects as go
from plotly.subplots import make_subplots
RANDOM_SEED = 142
from pycaret.regression import *

# %%
# load dataset
pd_data = pd.read_csv("preprocessed_data.csv")

#TODO drop Helsingfors

pd_data.drop(columns="season", inplace=True)
pd_data['time'] = pd.to_datetime(pd_data['time'])

# %%
pd_data.describe()
# Out:
#                                 time   consumption   temperature  \
# count                          49494  49494.000000  49494.000000
# mean   2022-10-11 02:25:46.223784704      3.509242      6.554019
# min              2022-04-07 21:00:00      0.000000    -17.299999
# 25%              2022-07-19 03:00:00      1.263256      1.000000
# 50%              2022-10-13 01:00:00      2.376530      6.800000
# 75%              2023-01-06 23:00:00      5.189000     12.100000
# max              2023-04-02 21:00:00     18.045011     30.500000
# std                              NaN      3.096356      7.630308
#
#             day_sin       day_cos      week_sin      week_cos      year_sin  \
# count  4.949400e+04  4.949400e+04  4.949400e+04  4.949400e+04  49494.000000
# mean  -1.170961e-04  3.137581e-05  5.610982e-03 -2.965490e-03     -0.039578
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00     -1.000000
# 25%   -7.071068e-01 -7.071068e-01 -7.071068e-01 -7.071068e-01     -0.738660
# 50%    1.502728e-14  6.386783e-14  9.808024e-13 -5.667275e-13     -0.081229
# 75%    7.071068e-01  7.071068e-01  7.071068e-01  7.071068e-01      0.663181
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00      1.000000
# std    7.071510e-01  7.070768e-01  7.073498e-01  7.068494e-01      0.703787
#
#            year_cos
# count  49494.000000
# mean       0.034882
# min       -1.000000
# 25%       -0.677781
# 50%        0.092330
# 75%        0.738919
# max        1.000000
# std        0.708464

# %% [markdown]
# ## Add consumption last week feature ##

# %%
pd_data['consumption_last_week'] = pd_data['consumption'].shift(7)

# %%
pd_data.head()
# Out:
#                  time   location  consumption  temperature   day_sin  \
# 0 2022-04-07 21:00:00     bergen     1.113325         -0.3 -0.965926
# 1 2022-04-07 21:00:00       oslo     4.092830          1.0 -0.965926
# 2 2022-04-07 21:00:00  stavanger     2.057858          1.3 -0.965926
# 3 2022-04-07 21:00:00     tromsø     1.246582         -3.9 -0.965926
# 4 2022-04-07 21:00:00  trondheim     1.970098         -2.8 -0.965926
#
#     day_cos  week_sin  week_cos  year_sin  year_cos  consumption_last_week
# 0  0.258819  0.652287  0.757972  0.994904 -0.100827                    NaN
# 1  0.258819  0.652287  0.757972  0.994904 -0.100827                    NaN
# 2  0.258819  0.652287  0.757972  0.994904 -0.100827                    NaN
# 3  0.258819  0.652287  0.757972  0.994904 -0.100827                    NaN
# 4  0.258819  0.652287  0.757972  0.994904 -0.100827                    NaN

# %%
pd_data[pd_data["consumption_last_week"].isna()].describe()
# Out:
#                                 time  consumption  temperature   day_sin  \
# count                              7     7.000000     7.000000  7.000000
# mean   2022-04-07 21:17:08.571428608     2.192731    -0.614286 -0.937383
# min              2022-04-07 21:00:00     1.050327    -3.900000 -0.965926
# 25%              2022-04-07 21:00:00     1.179953    -1.550000 -0.965926
# 50%              2022-04-07 21:00:00     1.970098     0.000000 -0.965926
# 75%              2022-04-07 21:30:00     2.937977     0.700000 -0.915976
# max              2022-04-07 22:00:00     4.092830     1.300000 -0.866025
# std                              NaN     1.270521     1.972670  0.048746
#
#         day_cos  week_sin  week_cos  year_sin  year_cos  consumption_last_week
# count  7.000000  7.000000  7.000000  7.000000  7.000000                    0.0
# mean   0.327728  0.660255  0.750852  0.994883 -0.101030                    NaN
# min    0.258819  0.652287  0.733052  0.994831 -0.101540                    NaN
# 25%    0.258819  0.652287  0.745512  0.994868 -0.101183                    NaN
# 50%    0.258819  0.652287  0.757972  0.994904 -0.100827                    NaN
# 75%    0.379410  0.666230  0.757972  0.994904 -0.100827                    NaN
# max    0.500000  0.680173  0.757972  0.994904 -0.100827                    NaN
# std    0.117684  0.013607  0.012160  0.000035  0.000348                    NaN

# %%
pd_data.to_csv("experiment1_data.csv")

# %% [markdown]
# # Split into test and train data for each location #

# %%
# Make split on each location

# TODO MUST MAKE DATA FOR EACH LOCATION
def select_location(dataset, location):
    dataset = pd_data[pd_data["location"] == location].reset_index().drop(columns= ["index", "location"])
    return dataset

oslo = select_location(pd_data, "oslo")
bergen = select_location(pd_data, "bergen")
trondheim = select_location(pd_data, "trondheim")
tromsø = select_location(pd_data, "tromsø")
stavanger = select_location(pd_data, "stavanger")






#pd_data.describe()
oslo.head()
# Out:
#                  time  consumption  temperature   day_sin   day_cos  week_sin  \
# 0 2022-04-07 21:00:00     4.092830          1.0 -0.965926  0.258819  0.652287
# 1 2022-04-07 22:00:00     3.818095          0.4 -0.866025  0.500000  0.680173
# 2 2022-04-07 23:00:00     3.660981          0.3 -0.707107  0.707107  0.707107
# 3 2022-04-08 00:00:00     3.584066          0.2 -0.500000  0.866025  0.733052
# 4 2022-04-08 01:00:00     3.549536          0.4 -0.258819  0.965926  0.757972
#
#    week_cos  year_sin  year_cos  consumption_last_week
# 0  0.757972  0.994904 -0.100827                    NaN
# 1  0.733052  0.994831 -0.101540                    NaN
# 2  0.707107  0.994758 -0.102253               1.970098
# 3  0.680173  0.994685 -0.102966               1.839443
# 4  0.652287  0.994611 -0.103679               1.747675

# %%
pd_data.head(-10)
# Out:
#                      time     location  consumption  temperature   day_sin  \
# 0     2022-04-07 21:00:00       bergen     1.113325         -0.3 -0.965926
# 1     2022-04-07 21:00:00         oslo     4.092830          1.0 -0.965926
# 2     2022-04-07 21:00:00    stavanger     2.057858          1.3 -0.965926
# 3     2022-04-07 21:00:00       tromsø     1.246582         -3.9 -0.965926
# 4     2022-04-07 21:00:00    trondheim     1.970098         -2.8 -0.965926
# ...                   ...          ...          ...          ...       ...
# 49479 2023-04-02 19:00:00    stavanger     6.060454          2.8 -0.965926
# 49480 2023-04-02 19:00:00       tromsø     2.095099         -2.3 -0.965926
# 49481 2023-04-02 19:00:00    trondheim     4.093120          1.4 -0.965926
# 49482 2023-04-02 20:00:00       bergen     3.328194          2.5 -1.000000
# 49483 2023-04-02 20:00:00  helsingfors     6.340000         -1.2 -1.000000
#
#             day_cos  week_sin  week_cos  year_sin  year_cos  \
# 0      2.588190e-01  0.652287  0.757972  0.994904 -0.100827
# 1      2.588190e-01  0.652287  0.757972  0.994904 -0.100827
# 2      2.588190e-01  0.652287  0.757972  0.994904 -0.100827
# 3      2.588190e-01  0.652287  0.757972  0.994904 -0.100827
# 4      2.588190e-01  0.652287  0.757972  0.994904 -0.100827
# ...             ...       ...       ...       ...       ...
# 49479 -2.588190e-01 -0.185912 -0.982566  0.999956 -0.009379
# 49480 -2.588190e-01 -0.185912 -0.982566  0.999956 -0.009379
# 49481 -2.588190e-01 -0.185912 -0.982566  0.999956 -0.009379
# 49482 -6.165360e-12 -0.222521 -0.974928  0.999949 -0.010096
# 49483 -6.165360e-12 -0.222521 -0.974928  0.999949 -0.010096
#
#        consumption_last_week
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 49479              12.856381
# 49480               6.052910
# 49481               2.084384
# 49482               4.067940
# 49483               3.390738
#
# [49484 rows x 11 columns]

# %%
# Extract unseen data to compare with final model
def split_test_train(dataset):
    # Calculate the index at which to split
    # split_index = int(len(dataset) -46) used when test was only last 24 hours
    split_index = int(len(dataset) * 0.8) 

    # Split into training and testing sets
    train_df = dataset.iloc[:split_index]
    test_df = dataset.iloc[split_index:] 

    return train_df, test_df


oslo_train, oslo_test = split_test_train(oslo)
bergen_train, bergen_test = split_test_train(bergen)
trondheim_train, trondheim_test = split_test_train(trondheim)
tromsø_train, tromsø_test = split_test_train(tromsø)
stavanger_train, stavanger_test = split_test_train(stavanger)

stavanger_test
# Out:
#                     time  consumption  temperature       day_sin  \
# 6912 2023-01-20 21:00:00     7.201020         -5.6 -8.660254e-01
# 6913 2023-01-20 22:00:00     7.150055         -5.4 -7.071068e-01
# 6914 2023-01-20 23:00:00     6.976293         -5.1 -5.000000e-01
# 6915 2023-01-21 00:00:00     6.884066         -5.1 -2.588190e-01
# 6916 2023-01-21 01:00:00     6.793396         -4.8 -1.263327e-11
# ...                  ...          ...          ...           ...
# 8636 2023-04-02 17:00:00     5.676252          5.8 -7.071068e-01
# 8637 2023-04-02 18:00:00     6.052910          4.6 -8.660254e-01
# 8638 2023-04-02 19:00:00     6.060454          2.8 -9.659258e-01
# 8639 2023-04-02 20:00:00     5.875634          1.4 -1.000000e+00
# 8640 2023-04-02 21:00:00     5.622820          0.5 -9.659258e-01
#
#            day_cos  week_sin  week_cos  year_sin  year_cos  \
# 6912  5.000000e-01  0.997204 -0.074730  0.336997  0.941506
# 6913  7.071068e-01  0.993712 -0.111964  0.337672  0.941264
# 6914  8.660254e-01  0.988831 -0.149042  0.338347  0.941022
# 6915  9.659258e-01  0.982566 -0.185912  0.339021  0.940779
# 6916  1.000000e+00  0.974928 -0.222521  0.339695  0.940536
# ...            ...       ...       ...       ...       ...
# 8636 -7.071068e-01 -0.111964 -0.993712  0.999968 -0.007945
# 8637 -5.000000e-01 -0.149042 -0.988831  0.999962 -0.008662
# 8638 -2.588190e-01 -0.185912 -0.982566  0.999956 -0.009379
# 8639 -6.165360e-12 -0.222521 -0.974928  0.999949 -0.010096
# 8640  2.588190e-01 -0.258819 -0.965926  0.999942 -0.010812
#
#       consumption_last_week
# 6912              14.965746
# 6913              14.766486
# 6914              14.572231
# 6915              14.215177
# 6916              13.942359
# ...                     ...
# 8636              11.643800
# 8637              12.410225
# 8638              12.856381
# 8639              13.010338
# 8640              12.738356
#
# [1729 rows x 10 columns]

# %% [markdown]
# # Experiment 1: Pv_measurement from last week as a feature #

# %%
location_train_dict = {"oslo": oslo_train, "trondheim": trondheim_train, "tromsø": tromsø_train, "stavanger": stavanger_train, "bergen": bergen_train}
location_test_dict = {"oslo": oslo_test, "trondheim": trondheim_test, "tromsø": tromsø_test, "stavanger": stavanger_test, "bergen": bergen_test}

# %%
location_train_dict.keys()
# Out:
# dict_keys(['oslo', 'trondheim', 'tromsø', 'stavanger', 'bergen'])

# %% [markdown]
# ### Running models with the extra feature ###

# %%
best_models = {}
model_comparisons = {}

for location in location_train_dict:
    location_train = location_train_dict[location]
    location_test = location_test_dict[location]

    print("\n---------------", location, "---------------\n")


    # Setup PyCaret environment for the current location
    s = setup(data=location_train, test_data=location_test, target='consumption',
              fold_strategy = 'timeseries', data_split_shuffle = False, fold_shuffle = False, session_id=123)
    
    # Compare models
    best = compare_models(sort='MAE')  
    model_comparisons[location] = pull()  # Pull the model comparison results for later referance

    # Tune and finalize model #TODO not added yet to save time
    # best = tune_model(best, optimize = "MAE",  n_iter=10) Not necessary - original model performs better at 10 iterations so save the time
    best = finalize_model(best)

    # Store the best model
    best_models[location] = best


# model_comparisons now contains comparison data for each location
# best_models contains the best model for each location
# Out:
# --------------- oslo ---------------
# <style type="text/css">
# #T_f3f02_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f3f02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3f02_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f3f02_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3f02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3f02_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f3f02_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3f02_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f3f02_row1_col1" class="data row1 col1" >consumption</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3f02_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f3f02_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3f02_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f3f02_row3_col1" class="data row3 col1" >(8641, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3f02_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f3f02_row4_col1" class="data row4 col1" >(8641, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3f02_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f3f02_row5_col1" class="data row5 col1" >(6912, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f3f02_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f3f02_row6_col1" class="data row6 col1" >(1729, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f3f02_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f3f02_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f3f02_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_f3f02_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f3f02_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_f3f02_row9_col1" class="data row9 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f3f02_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f3f02_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f3f02_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f3f02_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f3f02_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_f3f02_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f3f02_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_f3f02_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f3f02_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_f3f02_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f3f02_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_f3f02_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f3f02_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_f3f02_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f3f02_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_f3f02_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f3f02_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_f3f02_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f3f02_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_f3f02_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f3f02_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f3f02_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_f3f02_row20_col1" class="data row20 col1" >a6c8</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1fc8f th {
#   text-align: left;
# }
# #T_1fc8f_row0_col0, #T_1fc8f_row0_col2, #T_1fc8f_row1_col0, #T_1fc8f_row1_col1, #T_1fc8f_row1_col3, #T_1fc8f_row1_col4, #T_1fc8f_row1_col5, #T_1fc8f_row1_col6, #T_1fc8f_row2_col0, #T_1fc8f_row2_col1, #T_1fc8f_row2_col2, #T_1fc8f_row2_col3, #T_1fc8f_row2_col4, #T_1fc8f_row2_col5, #T_1fc8f_row2_col6, #T_1fc8f_row3_col0, #T_1fc8f_row3_col1, #T_1fc8f_row3_col2, #T_1fc8f_row3_col3, #T_1fc8f_row3_col4, #T_1fc8f_row3_col5, #T_1fc8f_row3_col6, #T_1fc8f_row4_col0, #T_1fc8f_row4_col1, #T_1fc8f_row4_col2, #T_1fc8f_row4_col3, #T_1fc8f_row4_col4, #T_1fc8f_row4_col5, #T_1fc8f_row4_col6, #T_1fc8f_row5_col0, #T_1fc8f_row5_col1, #T_1fc8f_row5_col2, #T_1fc8f_row5_col3, #T_1fc8f_row5_col4, #T_1fc8f_row5_col5, #T_1fc8f_row5_col6, #T_1fc8f_row6_col0, #T_1fc8f_row6_col1, #T_1fc8f_row6_col2, #T_1fc8f_row6_col3, #T_1fc8f_row6_col4, #T_1fc8f_row6_col5, #T_1fc8f_row6_col6, #T_1fc8f_row7_col0, #T_1fc8f_row7_col1, #T_1fc8f_row7_col2, #T_1fc8f_row7_col3, #T_1fc8f_row7_col4, #T_1fc8f_row7_col5, #T_1fc8f_row7_col6, #T_1fc8f_row8_col0, #T_1fc8f_row8_col1, #T_1fc8f_row8_col2, #T_1fc8f_row8_col3, #T_1fc8f_row8_col4, #T_1fc8f_row8_col5, #T_1fc8f_row8_col6, #T_1fc8f_row9_col0, #T_1fc8f_row9_col1, #T_1fc8f_row9_col2, #T_1fc8f_row9_col3, #T_1fc8f_row9_col4, #T_1fc8f_row9_col5, #T_1fc8f_row9_col6, #T_1fc8f_row10_col0, #T_1fc8f_row10_col1, #T_1fc8f_row10_col2, #T_1fc8f_row10_col3, #T_1fc8f_row10_col4, #T_1fc8f_row10_col5, #T_1fc8f_row10_col6, #T_1fc8f_row11_col0, #T_1fc8f_row11_col1, #T_1fc8f_row11_col2, #T_1fc8f_row11_col3, #T_1fc8f_row11_col4, #T_1fc8f_row11_col5, #T_1fc8f_row11_col6, #T_1fc8f_row12_col0, #T_1fc8f_row12_col1, #T_1fc8f_row12_col2, #T_1fc8f_row12_col3, #T_1fc8f_row12_col4, #T_1fc8f_row12_col5, #T_1fc8f_row12_col6, #T_1fc8f_row13_col0, #T_1fc8f_row13_col1, #T_1fc8f_row13_col2, #T_1fc8f_row13_col3, #T_1fc8f_row13_col4, #T_1fc8f_row13_col5, #T_1fc8f_row13_col6, #T_1fc8f_row14_col0, #T_1fc8f_row14_col1, #T_1fc8f_row14_col2, #T_1fc8f_row14_col3, #T_1fc8f_row14_col4, #T_1fc8f_row14_col5, #T_1fc8f_row14_col6, #T_1fc8f_row15_col0, #T_1fc8f_row15_col1, #T_1fc8f_row15_col2, #T_1fc8f_row15_col3, #T_1fc8f_row15_col4, #T_1fc8f_row15_col5, #T_1fc8f_row15_col6, #T_1fc8f_row16_col0, #T_1fc8f_row16_col1, #T_1fc8f_row16_col2, #T_1fc8f_row16_col3, #T_1fc8f_row16_col4, #T_1fc8f_row16_col5, #T_1fc8f_row16_col6, #T_1fc8f_row17_col0, #T_1fc8f_row17_col1, #T_1fc8f_row17_col2, #T_1fc8f_row17_col3, #T_1fc8f_row17_col4, #T_1fc8f_row17_col5, #T_1fc8f_row17_col6 {
#   text-align: left;
# }
# #T_1fc8f_row0_col1, #T_1fc8f_row0_col3, #T_1fc8f_row0_col4, #T_1fc8f_row0_col5, #T_1fc8f_row0_col6, #T_1fc8f_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1fc8f_row0_col7, #T_1fc8f_row1_col7, #T_1fc8f_row2_col7, #T_1fc8f_row3_col7, #T_1fc8f_row4_col7, #T_1fc8f_row5_col7, #T_1fc8f_row6_col7, #T_1fc8f_row7_col7, #T_1fc8f_row8_col7, #T_1fc8f_row9_col7, #T_1fc8f_row10_col7, #T_1fc8f_row11_col7, #T_1fc8f_row12_col7, #T_1fc8f_row13_col7, #T_1fc8f_row14_col7, #T_1fc8f_row15_col7, #T_1fc8f_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1fc8f_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1fc8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fc8f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1fc8f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1fc8f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1fc8f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1fc8f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1fc8f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1fc8f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1fc8f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fc8f_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_1fc8f_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_1fc8f_row0_col1" class="data row0 col1" >0.9105</td>
#       <td id="T_1fc8f_row0_col2" class="data row0 col2" >2.3831</td>
#       <td id="T_1fc8f_row0_col3" class="data row0 col3" >1.1036</td>
#       <td id="T_1fc8f_row0_col4" class="data row0 col4" >-0.1383</td>
#       <td id="T_1fc8f_row0_col5" class="data row0 col5" >0.1406</td>
#       <td id="T_1fc8f_row0_col6" class="data row0 col6" >0.1279</td>
#       <td id="T_1fc8f_row0_col7" class="data row0 col7" >0.1250</td>
#     </tr>
#     <tr>
#       <th id="T_1fc8f_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_1fc8f_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_1fc8f_row1_col1" class="data row1 col1" >0.9301</td>
#       <td id="T_1fc8f_row1_col2" class="data row1 col2" >2.2337</td>
#       <td id="T_1fc8f_row1_col3" class="data row1 col3" >1.1348</td>
#       <td id="T_1fc8f_row1_col4" class="data row1 col4" >-0.2267</td>
#       <td id="T_1fc8f_row1_col5" class="data row1 col5" >0.1494</td>
#       <td id="T_1fc8f_row1_col6" class="data row1 col6" >0.1384</td>
#       <td id="T_1fc8f_row1_col7" class="data row1 col7" >0.0600</td>
#     </tr>
#     <tr>
#       <th id="T_1fc8f_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_1fc8f_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_1fc8f_row2_col1" class="data row2 col1" >0.9532</td>
#       <td id="T_1fc8f_row2_col2" class="data row2 col2" >2.4497</td>
#       <td id="T_1fc8f_row2_col3" class="data row2 col3" >1.1623</td>
#       <td id="T_1fc8f_row2_col4" class="data row2 col4" >-0.3830</td>
#       <td id="T_1fc8f_row2_col5" class="data row2 col5" >0.1539</td>
#       <td id="T_1fc8f_row2_col6" class="data row2 col6" >0.1367</td>
#       <td id="T_1fc8f_row2_col7" class="data row2 col7" >0.2760</td>
#     </tr>
#     <tr>
#       <th id="T_1fc8f_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_1fc8f_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1fc8f_row3_col1" class="data row3 col1" >0.9573</td>
#       <td id="T_1fc8f_row3_col2" class="data row3 col2" >2.4868</td>
#       <td id="T_1fc8f_row3_col3" class="data row3 col3" >1.1580</td>
#       <td id="T_1fc8f_row3_col4" class="data row3 col4" >-0.3405</td>
#       <td id="T_1fc8f_row3_col5" class="data row3 col5" >0.1526</td>
#       <td id="T_1fc8f_row3_col6" class="data row3 col6" >0.1360</td>
#       <td id="T_1fc8f_row3_col7" class="data row3 col7" >0.7850</td>
#     </tr>
#     <tr>
#       <th id="T_1fc8f_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_1fc8f_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T
row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a8960">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8960_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a8960_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8960_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8960_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a8960_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8960_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a8960_row1_col1" class="data row1 col1" >consumption</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8960_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a8960_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8960_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a8960_row3_col1" class="data row3 col1" >(8641, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8960_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a8960_row4_col1" class="data row4 col1" >(8641, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8960_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a8960_row5_col1" class="data row5 col1" >(6912, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a8960_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a8960_row6_col1" class="data row6 col1" >(1729, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a8960_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a8960_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a8960_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_a8960_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a8960_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_a8960_row9_col1" class="data row9 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a8960_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_a8960_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a8960_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_a8960_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a8960_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_a8960_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a8960_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_a8960_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a8960_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_a8960_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a8960_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_a8960_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a8960_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_a8960_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a8960_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_a8960_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a8960_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_a8960_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a8960_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_a8960_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a8960_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a8960_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_a8960_row20_col1" class="data row20 col1" >5ffe</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fd848 th {
#   text-align: left;
# }
# #T_fd848_row0_col0, #T_fd848_row0_col3, #T_fd848_row1_col0, #T_fd848_row1_col1, #T_fd848_row1_col2, #T_fd848_row1_col4, #T_fd848_row1_col5, #T_fd848_row1_col6, #T_fd848_row2_col0, #T_fd848_row2_col1, #T_fd848_row2_col2, #T_fd848_row2_col3, #T_fd848_row2_col4, #T_fd848_row2_col5, #T_fd848_row2_col6, #T_fd848_row3_col0, #T_fd848_row3_col1, #T_fd848_row3_col2, #T_fd848_row3_col3, #T_fd848_row3_col4, #T_fd848_row3_col5, #T_fd848_row3_col6, #T_fd848_row4_col0, #T_fd848_row4_col1, #T_fd848_row4_col2, #T_fd848_row4_col3, #T_fd848_row4_col4, #T_fd848_row4_col5, #T_fd848_row4_col6, #T_fd848_row5_col0, #T_fd848_row5_col1, #T_fd848_row5_col2, #T_fd848_row5_col3, #T_fd848_row5_col4, #T_fd848_row5_col5, #T_fd848_row5_col6, #T_fd848_row6_col0, #T_fd848_row6_col1, #T_fd848_row6_col2, #T_fd848_row6_col3, #T_fd848_row6_col4, #T_fd848_row6_col5, #T_fd848_row6_col6, #T_fd848_row7_col0, #T_fd848_row7_col1, #T_fd848_row7_col2, #T_fd848_row7_col3, #T_fd848_row7_col4, #T_fd848_row7_col5, #T_fd848_row7_col6, #T_fd848_row8_col0, #T_fd848_row8_col1, #T_fd848_row8_col2, #T_fd848_row8_col3, #T_fd848_row8_col4, #T_fd848_row8_col5, #T_fd848_row8_col6, #T_fd848_row9_col0, #T_fd848_row9_col1, #T_fd848_row9_col2, #T_fd848_row9_col3, #T_fd848_row9_col4, #T_fd848_row9_col5, #T_fd848_row9_col6, #T_fd848_row10_col0, #T_fd848_row10_col1, #T_fd848_row10_col2, #T_fd848_row10_col3, #T_fd848_row10_col4, #T_fd848_row10_col5, #T_fd848_row10_col6, #T_fd848_row11_col0, #T_fd848_row11_col1, #T_fd848_row11_col2, #T_fd848_row11_col3, #T_fd848_row11_col4, #T_fd848_row11_col5, #T_fd848_row11_col6, #T_fd848_row12_col0, #T_fd848_row12_col1, #T_fd848_row12_col2, #T_fd848_row12_col3, #T_fd848_row12_col4, #T_fd848_row12_col5, #T_fd848_row12_col6, #T_fd848_row13_col0, #T_fd848_row13_col1, #T_fd848_row13_col2, #T_fd848_row13_col3, #T_fd848_row13_col4, #T_fd848_row13_col5, #T_fd848_row13_col6, #T_fd848_row14_col0, #T_fd848_row14_col1, #T_fd848_row14_col2, #T_fd848_row14_col3, #T_fd848_row14_col4, #T_fd848_row14_col5, #T_fd848_row14_col6, #T_fd848_row15_col0, #T_fd848_row15_col1, #T_fd848_row15_col2, #T_fd848_row15_col3, #T_fd848_row15_col4, #T_fd848_row15_col5, #T_fd848_row15_col6, #T_fd848_row16_col0, #T_fd848_row16_col1, #T_fd848_row16_col2, #T_fd848_row16_col3, #T_fd848_row16_col4, #T_fd848_row16_col5, #T_fd848_row16_col6, #T_fd848_row17_col0, #T_fd848_row17_col1, #T_fd848_row17_col2, #T_fd848_row17_col3, #T_fd848_row17_col4, #T_fd848_row17_col5, #T_fd848_row17_col6 {
#   text-align: left;
# }
# #T_fd848_row0_col1, #T_fd848_row0_col2, #T_fd848_row0_col4, #T_fd848_row0_col5, #T_fd848_row0_col6, #T_fd848_row1_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fd848_row0_col7, #T_fd848_row1_col7, #T_fd848_row2_col7, #T_fd848_row3_col7, #T_fd848_row4_col7, #T_fd848_row5_col7, #T_fd848_row6_col7, #T_fd848_row7_col7, #T_fd848_row8_col7, #T_fd848_row9_col7, #T_fd848_row11_col7, #T_fd848_row12_col7, #T_fd848_row13_col7, #T_fd848_row14_col7, #T_fd848_row16_col7, #T_fd848_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fd848_row10_col7, #T_fd848_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fd848">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd848_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fd848_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fd848_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fd848_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fd848_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fd848_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fd848_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fd848_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd848_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_fd848_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fd848_row0_col1" class="data row0 col1" >0.1229</td>
#       <td id="T_fd848_row0_col2" class="data row0 col2" >0.0282</td>
#       <td id="T_fd848_row0_col3" class="data row0 col3" >0.1501</td>
#       <td id="T_fd848_row0_col4" class="data row0 col4" >0.1646</td>
#       <td id="T_fd848_row0_col5" class="data row0 col5" >0.0667</td>
#       <td id="T_fd848_row0_col6" class="data row0 col6" >0.1066</td>
#       <td id="T_fd848_row0_col7" class="data row0 col7" >0.1450</td>
#     </tr>
#     <tr>
#       <th id="T_fd848_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_fd848_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fd848_row1_col1" class="data row1 col1" >0.1236</td>
#       <td id="T_fd848_row1_col2" class="data row1 col2" >0.0299</td>
#       <td id="T_fd848_row1_col3" class="data row1 col3" >0.1495</td>
#       <td id="T_fd848_row1_col4" class="data row1 col4" >0.1203</td>
#       <td id="T_fd848_row1_col5" class="data row1 col5" >0.0671</td>
#       <td id="T_fd848_row1_col6" class="data row1 col6" >0.1083</td>
#       <td id="T_fd848_row1_col7" class="data row1 col7" >0.8210</td>
#     </tr>
#     <tr>
#       <th id="T_fd848_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_fd848_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_fd848_row2_col1" class="data row2 col1" >0.1316</td>
#       <td id="T_fd848_row2_col2" class="data row2 col2" >0.0335</td>
#       <td id="T_fd848_row2_col3" class="data row2 col3" >0.1587</td>
#       <td id="T_fd848_row2_col4" class="data row2 col4" >0.0100</td>
#       <td id="T_fd848_row2_col5" class="data row2 col5" >0.0713</td>
#       <td id="T_fd848_row2_col6" class="data row2 col6" >0.1158</td>
#       <td id="T_fd848_row2_col7" class="data row2 col7" >0.2610</td>
#     </tr>
#     <tr>
#       <th id="T_fd848_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T
>0.1700</td>
#     </tr>
#     <tr>
#       <th id="T_8f984_level0_

# %% [markdown]
# ### Running models WITHOUT the extra feature ###

# %%
oslo_train_wo_lastweek = oslo_train.drop(columns="consumption_last_week")
trondheim_train_wo_lastweek = trondheim_train.drop(columns="consumption_last_week")
tromsø_train_wo_lastweek = tromsø_train.drop(columns="consumption_last_week")
stavanger_train_wo_lastweek = stavanger_train.drop(columns="consumption_last_week")
bergen_train_wo_lastweek = bergen_train.drop(columns="consumption_last_week")

oslo_test_wo_lastweek = oslo_test.drop(columns="consumption_last_week")
trondheim_test_wo_lastweek = trondheim_test.drop(columns="consumption_last_week")
tromsø_test_wo_lastweek = tromsø_test.drop(columns="consumption_last_week")
stavanger_test_wo_lastweek = stavanger_test.drop(columns="consumption_last_week")
bergen_test_wo_lastweek = bergen_test.drop(columns="consumption_last_week")


location_train_dict_wo_lastweek = {"oslo": oslo_train_wo_lastweek, "trondheim": trondheim_train_wo_lastweek, "tromsø": tromsø_train_wo_lastweek,
                                   "stavanger": stavanger_train_wo_lastweek, "bergen": bergen_train_wo_lastweek}

location_test_dict_wo_lastweek = {"oslo": oslo_test_wo_lastweek, "trondheim": trondheim_test_wo_lastweek, "tromsø": tromsø_test_wo_lastweek,
                                   "stavanger": stavanger_test_wo_lastweek, "bergen": bergen_test_wo_lastweek}
best_models_wo_lastweek = {}
model_comparisons_wo_lastweek = {}

for location in location_train_dict_wo_lastweek:
    location_train = location_train_dict_wo_lastweek[location]
    location_test = location_test_dict_wo_lastweek[location]

    print("\n---------------", location, "---------------\n")


    # Setup PyCaret environment for the current location
    s = setup(data=location_train, test_data=location_test, target='consumption',
              fold_strategy = 'timeseries', data_split_shuffle = False, fold_shuffle = False, session_id=123)
    
    # Compare models
    best = compare_models(sort='MAE')  # TODO Correct metric?
    model_comparisons_wo_lastweek[location] = pull()  # Pull the model comparison results for later referance

    # Tune and finalize model #TODO not added yet to save time
    # best = tune_model(best, optimize = "MAE", n_iter=10) Not necessary - original model performs better at 10 iterations so save the time
    best = finalize_model(best)

    # Store the best model
    best_models_wo_lastweek[location] = best
# Out:
# --------------- oslo ---------------
# <style type="text/css">
# #T_1d607_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1d607">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d607_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1d607_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d607_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d607_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1d607_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1d607_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1d607_row1_col1" class="data row1 col1" >consumption</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1d607_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1d607_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1d607_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1d607_row3_col1" class="data row3 col1" >(8641, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1d607_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1d607_row4_col1" class="data row4 col1" >(8641, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1d607_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1d607_row5_col1" class="data row5 col1" >(6912, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1d607_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1d607_row6_col1" class="data row6 col1" >(1729, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1d607_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_1d607_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1d607_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_1d607_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1d607_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_1d607_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1d607_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_1d607_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1d607_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_1d607_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1d607_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_1d607_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1d607_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_1d607_row13_col1" class="data row13 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1d607_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_1d607_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1d607_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_1d607_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1d607_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_1d607_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1d607_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_1d607_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1d607_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_1d607_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1d607_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1d607_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_1d607_row19_col1" class="data row19 col1" >36f4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T
_ee21b_row4_col5, #T_ee21b_row4_col6, #T_ee21b_row5_col0, #T_ee21b_row5_col1, #T_ee21b_row5_col2, #T_ee21b_row5_col3, #T_ee21b_row5_col4, #T_ee21b_row5_col5, #T_ee21b_row5_col6, #T_ee21b_row6_col0, #T_ee21b_row6_col1, #T_ee21b_row6_col2, #T_ee21b_row6_col3, #T_ee21b_row6_col4, #T_ee21b_row6_col5, #T_ee21b_row6_col6, #T_ee21b_row7_col0, #T_ee21b_row7_col1, #T_ee21b_row7_col2, #T_ee21b_row7_col3, #T_ee21b_row7_col4, #T_ee21b_row7_col5, #T_ee21b_row7_col6, #T_ee21b_row8_col0, #T_ee21b_row8_col1, #T_ee21b_row8_col2, #T_ee21b_row8_col3, #T_ee21b_row8_col4, #T_ee21b_row8_col5, #T_ee21b_row8_col6, #T_ee21b_row9_col0, #T_ee21b_row9_col1, #T_ee21b_row9_col2, #T_ee21b_row9_col3, #T_ee21b_row9_col4, #T_ee21b_row9_col5, #T_ee21b_row9_col6, #T_ee21b_row10_col0, #T_ee21b_row10_col1, #T_ee21b_row10_col2, #T_ee21b_row10_col3, #T_ee21b_row10_col4, #T_ee21b_row10_col5, #T_ee21b_row10_col6, #T_ee21b_row11_col0, #T_ee21b_row11_col1, #T_ee21b_row11_col2, #T_ee21b_row11_col3, #T_ee21b_row11_col4, #T_ee21b_row11_col5, #T_ee21b_row11_col6, #T_ee21b_row12_col0, #T_ee21b_row12_col1, #T_ee21b_row12_col2, #T_ee21b_row12_col3, #T_ee21b_row12_col4, #T_ee21b_row12_col5, #T_ee21b_row12_col6, #T_ee21b_row13_col0, #T_ee21b_row13_col1, #T_ee21b_row13_col2, #T_ee21b_row13_col3, #T_ee21b_row13_col4, #T_ee21b_row13_col5, #T_ee21b_row13_col6, #T_ee21b_row14_col0, #T_ee21b_row14_col1, #T_ee21b_row14_col2, #T_ee21b_row14_col3, #T_ee21b_row14_col4, #T_ee21b_row14_col5, #T_ee21b_row14_col6, #T_ee21b_row15_col0, #T_ee21b_row15_col1, #T_ee21b_row15_col2, #T_ee21b_row15_col3, #T_ee21b_row15_col4, #T_ee21b_row15_col5, #T_ee21b_row15_col6, #T_ee21b_row16_col0, #T_ee21b_row16_col1, #T_ee21b_row16_col2, #T_ee21b_row16_col3, #T_ee21b_row16_col4, #T_ee21b_row16_col5, #T_ee21b_row16_col6, #T_ee21b_row17_col0, #T_ee21b_row17_col1, #T_ee21b_row17_col2, #T_ee21b_row17_col3, #T_ee21b_row17_col4, #T_ee21b_row17_col5, #T_ee21b_row17_col6 {
#   text-align: left;
# }
# #T_ee21b_row0_col1, #T_ee21b_row0_col2, #T_ee21b_row0_col3, #T_ee21b_row0_col4, #T_ee21b_row0_col5, #T_ee21b_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ee21b_row0_col7, #T_ee21b_row1_col7, #T_ee21b_row2_col7, #T_ee21b_row3_col7, #T_ee21b_row4_col7, #T_ee21b_row5_col7, #T_ee21b_row6_col7, #T_ee21b_row7_col7, #T_ee21b_row8_col7, #T_ee21b_row11_col7, #T_ee21b_row12_col7, #T_ee21b_row13_col7, #T_ee21b_row14_col7, #T_ee21b_row15_col7, #T_ee21b_row16_col7, #T_ee21b_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_
row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_ee21b_row5_col1" class="data row5 col1" >0.3143</td>
#       <td id="T_ee21b_row5_col2" class="data row5 col2" >0.2645</td>
#       <td id="T_ee21b_row5_col3" class="data row5 col3" >0.3697</td>
#       <td id="T_ee21b_row5_col4" class="data row5 col4" >-0.6907</td>
#       <td id="T_ee21b_row5_col5" class="data row5 col5" >0.1202</td>
#       <td id="T_ee21b_row5_col6" class="data row5 col6" >0.1486</td>
#       <td id="T_ee21b_row5_col7" class="data row5 col7" >0.1380</td>
#     </tr>
#     <tr>
#       <th id="T_ee21b_le

# %%
oslo_test.head()
# Out:
#                     time  consumption  temperature       day_sin   day_cos  \
# 6912 2023-01-20 21:00:00    14.766486        -12.5 -8.660254e-01  0.500000
# 6913 2023-01-20 22:00:00    14.572231        -13.1 -7.071068e-01  0.707107
# 6914 2023-01-20 23:00:00    14.215177        -13.0 -5.000000e-01  0.866025
# 6915 2023-01-21 00:00:00    13.942359        -13.2 -2.588190e-01  0.965926
# 6916 2023-01-21 01:00:00    13.801610        -13.1 -1.263327e-11  1.000000
#
#       week_sin  week_cos  year_sin  year_cos  consumption_last_week
# 6912  0.997204 -0.074730  0.336997  0.941506                  6.470
# 6913  0.993712 -0.111964  0.337672  0.941264                  6.482
# 6914  0.988831 -0.149042  0.338347  0.941022                  6.463
# 6915  0.982566 -0.185912  0.339021  0.940779                  6.432
# 6916  0.974928 -0.222521  0.339695  0.940536                  6.438

# %% [markdown]
# ## Predict with all models and print MAE ##

# %%
# Prediction for models WITH last week


# Store all models with name for easier handling
best_models_dict = {}
i = 0

for location in location_test_dict:
    best_models_dict[location] = best_models[location]


#Store for easy plotting
plot_predictions = []
plot_actuals = []


predictions_with_lastweek = {}
for location in location_test_dict: 
    test = location_test_dict[location]
    test_X = test.drop(columns="consumption")
    test_y = test[["consumption", "time"]]


    model = best_models_dict[location]

    pred_y = predict_model(model, data = test_X)

    pred_y = pred_y[["prediction_label", "time"]]
    pred_y = pred_y.rename(columns={"prediction_label": "consumption"})
    plot_predictions.append(pred_y)
    plot_actuals.append(test_y)
    
    predictions_with_lastweek[location] = pred_y

# %%
# Prediction for models WO last week

# Store all models with name for easier handling
best_models_wo_lastweek_dict = {}

for location in location_test_dict:
    best_models_wo_lastweek_dict[location] = best_models_wo_lastweek[location]


predictions_wo_lastweek = {}
for location in location_test_dict: 
    test = location_test_dict[location]
    test_X = test.drop(columns=["consumption", "consumption_last_week"])
    test_y = test[["consumption", "time"]]

    model = best_models_wo_lastweek_dict[location]

    pred_y = predict_model(model, data = test_X)
    predictions_wo_lastweek[location] = pred_y

# %%
#Print all MAE in a table 

from sklearn.metrics import mean_absolute_error

MAE_df = pd.DataFrame(columns = ["location", "MAE with last_week_consumption", "MAE w/o last_week_consumption", "MAE baseline"])

i = 0
for location in predictions_with_lastweek:
    prediction_with_lastweek = predictions_with_lastweek[location]["consumption"]
    prediction_wo_lastweek = predictions_wo_lastweek[location]["prediction_label"] 

    actual = location_test_dict[location][["consumption", "consumption_last_week"]]

    MAE_with_lastweek = round(mean_absolute_error(actual["consumption"],prediction_with_lastweek), 3)
    MAE_wo_lastweek = round(mean_absolute_error(actual["consumption"],prediction_wo_lastweek), 3)
    MAE_baseline = round(mean_absolute_error(actual["consumption"], actual["consumption_last_week"]), 3)

    MAE_df.loc[i]= [location, MAE_with_lastweek, MAE_wo_lastweek, MAE_baseline]
    i+=1

MAE_df
# Out:
#     location  MAE with last_week_consumption  MAE w/o last_week_consumption  \
# 0       oslo                           0.430                          0.431
# 1  trondheim                           0.065                          0.126
# 2     tromsø                           0.060                          0.031
# 3  stavanger                           0.143                          0.048
# 4     bergen                           0.127                          0.126
#
#    MAE baseline
# 0         5.782
# 1         1.682
# 2         3.712
# 3         6.558
# 4         0.444

# %% [markdown]
# Key takeaway: better with last week consumotion than without

# %%
MAE_df.to_csv("Table Conclusion Experiment 1.csv")
# (MAE_df.drop(columns=["MAE w/o last_week_consumption", "MAE baseline"])).to_csv("Tables for chap. 4/MAE_locationmodels.csv")

# %%
# SAve preferred models
# Extract the minimum value from the MAE columns for each location
MAE_df['min_MAE'] = MAE_df[['MAE with last_week_consumption', 'MAE w/o last_week_consumption', 'MAE baseline']].min(axis=1)

# Create a new dataframe with the location and the corresponding minimum MAE value
result_df = MAE_df[['location', 'min_MAE']]
result_df["model"] = ["GBR", "lightGBM", "lightGBM", "random forest", "GBR"]
result_df["last_week_consumption"] = ["yes", "yes", "no", "no", "no"]
result_df.to_csv("MAE_best_locationmodels.csv")
MAE_df.drop(columns="min_MAE", inplace=True)
MAE_df.to_csv("MAE_all_locationmodels.csv")

# %% [markdown]
# ### Plot all predictions ###

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 8)) # Create a subplot of 2 rows and 3 columns with a suitable figure size

i = 0
for location in location_test_dict: 
    prediction_with_lastweek_24hr = predictions_with_lastweek[location][-45:-22]
    prediction_wo_lastweek_24hr = predictions_wo_lastweek[location][-45:-22]
    actual = location_test_dict[location][["consumption", "consumption_last_week", "time"]][-45:-22] #To have the predictions in the right format, from 00:00 to 23:00, we leave out the last 21 entries

    
    # Map the index i to the appropriate row and column for the subplot
    row = i // 3
    col = i % 3

    ax = axes[row, col]  # Use the appropriate axis for this plot
    ax.plot(actual["time"], actual["consumption"], label="Actual Consumption")
    ax.plot(prediction_with_lastweek_24hr["time"], prediction_with_lastweek_24hr["consumption"], label="Predicted Consumption", linestyle="--")
    #ax.plot(prediction_wo_lastweek["time"], prediction_wo_lastweek["prediction_label"], label="Predicted Consumption", linestyle="-")
    # ax.plot(test_y["time"], actual["consumption_last_week"], label="Last week Consumption")


    ax.set_xlabel('Time')
    ax.set_ylabel('Consumption')
    ax.legend()
    ax.set_title(location)
    ax.grid(False)
    i += 1

# Hide any unused subplot (in this case, the last one)
axes[1, 2].axis('off')

# Adjust layout
plt.tight_layout()  
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 8))  # Create a subplot of 2 rows and 3 columns with a suitable figure size

i = 0
for location in location_test_dict:
    if i > 4:  # Skip if more than 5 locations to ensure only 5 plots are made
        break

    prediction_with_lastweek_24hr = predictions_with_lastweek[location][-45:-22]
    prediction_wo_lastweek_24hr = predictions_wo_lastweek[location][-45:-22]
    actual = location_test_dict[location][["consumption", "consumption_last_week", "time"]][-45:-22]

    # Map the index i to the appropriate row and column for the subplot
    row = i // 3
    col = i % 3

    ax = axes[row, col]  # Use the appropriate axis for this plot
    ax.plot(actual["time"], actual["consumption"], label="Actual Consumption")
    ax.plot(prediction_with_lastweek_24hr["time"], prediction_with_lastweek_24hr["consumption"], label="Predicted Consumption", linestyle="--")

    ax.set_xlabel('Time')
    ax.set_ylabel('Consumption')
    ax.legend()
    ax.set_title(location)
    ax.grid(False)
    i += 1

# Hide any unused subplot (in this case, the last one)
axes[1, 2].axis('off')

# Adjust layout to prevent overlapping of subplot titles and labels
plt.tight_layout()
plt.show()

# %%
trondheim_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1729 entries, 6912 to 8640
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time                   1729 non-null   datetime64[ns]
#  1   consumption            1729 non-null   float64
#  2   temperature            1729 non-null   float64
#  3   day_sin                1729 non-null   float64
#  4   day_cos                1729 non-null   float64
#  5   week_sin               1729 non-null   float64
#  6   week_cos               1729 non-null   float64
#  7   year_sin               1729 non-null   float64
#  8   year_cos               1729 non-null   float64
#  9   consumption_last_week  1729 non-null   float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 135.2 KB

# %%
trondheim_test
# Out:
#                     time  consumption  temperature       day_sin  \
# 6912 2023-01-20 21:00:00     4.006104         -0.6 -8.660254e-01
# 6913 2023-01-20 22:00:00     3.897353         -0.2 -7.071068e-01
# 6914 2023-01-20 23:00:00     3.762435         -1.8 -5.000000e-01
# 6915 2023-01-21 00:00:00     3.611077         -1.5 -2.588190e-01
# 6916 2023-01-21 01:00:00     3.492410         -1.6 -1.263327e-11
# ...                  ...          ...          ...           ...
# 8636 2023-04-02 17:00:00     3.927136          3.6 -7.071068e-01
# 8637 2023-04-02 18:00:00     4.067940          3.0 -8.660254e-01
# 8638 2023-04-02 19:00:00     4.093120          1.4 -9.659258e-01
# 8639 2023-04-02 20:00:00     3.990767         -2.7 -1.000000e+00
# 8640 2023-04-02 21:00:00     3.749047         -3.8 -9.659258e-01
#
#            day_cos  week_sin  week_cos  year_sin  year_cos  \
# 6912  5.000000e-01  0.997204 -0.074730  0.336997  0.941506
# 6913  7.071068e-01  0.993712 -0.111964  0.337672  0.941264
# 6914  8.660254e-01  0.988831 -0.149042  0.338347  0.941022
# 6915  9.659258e-01  0.982566 -0.185912  0.339021  0.940779
# 6916  1.000000e+00  0.974928 -0.222521  0.339695  0.940536
# ...            ...       ...       ...       ...       ...
# 8636 -7.071068e-01 -0.111964 -0.993712  0.999968 -0.007945
# 8637 -5.000000e-01 -0.149042 -0.988831  0.999962 -0.008662
# 8638 -2.588190e-01 -0.185912 -0.982566  0.999956 -0.009379
# 8639 -6.165360e-12 -0.222521 -0.974928  0.999949 -0.010096
# 8640  2.588190e-01 -0.258819 -0.965926  0.999942 -0.010812
#
#       consumption_last_week
# 6912               1.992874
# 6913               1.958859
# 6914               1.921207
# 6915               1.842272
# 6916               1.766286
# ...                     ...
# 8636               1.924264
# 8637               1.981428
# 8638               2.084384
# 8639               2.095099
# 8640               2.076341
#
# [1729 rows x 10 columns]

# %%
test_y = np.array(trondheim_test["consumption"])

# %%
test_x = trondheim_test.drop(columns="consumption")

# %%
test_x.head()
# Out:
#                     time  temperature       day_sin   day_cos  week_sin  \
# 6912 2023-01-20 21:00:00         -0.6 -8.660254e-01  0.500000  0.997204
# 6913 2023-01-20 22:00:00         -0.2 -7.071068e-01  0.707107  0.993712
# 6914 2023-01-20 23:00:00         -1.8 -5.000000e-01  0.866025  0.988831
# 6915 2023-01-21 00:00:00         -1.5 -2.588190e-01  0.965926  0.982566
# 6916 2023-01-21 01:00:00         -1.6 -1.263327e-11  1.000000  0.974928
#
#       week_cos  year_sin  year_cos  consumption_last_week
# 6912 -0.074730  0.336997  0.941506               1.992874
# 6913 -0.111964  0.337672  0.941264               1.958859
# 6914 -0.149042  0.338347  0.941022               1.921207
# 6915 -0.185912  0.339021  0.940779               1.842272
# 6916 -0.222521  0.339695  0.940536               1.766286

# %%
from explainerdashboard import RegressionExplainer
# dashboard(best_aggregated, display_format="inline") # https://www.youtube.com/watch?v=FZ5-GtdYez0

model = best_models_dict["trondheim"]
test_x['time'] = pd.to_datetime(trondheim_test['time'])
explainer = RegressionExplainer(model, X=test_x, y=test_y)
# Out:
# WARNING: Parameter shap='guess', but failed to guess the type of shap explainer to use for Pipeline. Defaulting to the model agnostic shap.KernelExplainer (shap='kernel'). However this will be slow, so if your model is compatible with e.g. shap.TreeExplainer or shap.LinearExplainer then pass shap='tree' or shap='linear'!
# WARNING: For shap='kernel', shap interaction values can unfortunately not be calculated!
# Warning: shap values for shap.KernelExplainer get calculated against X_background, but paramater X_background=None, so using shap.sample(X, 50) instead
# Generating self.shap_explainer = shap.KernelExplainer(model, X)...

# %%
from explainerdashboard import ExplainerDashboard

ExplainerDashboard(explainer).run()
# Out:
# Building ExplainerDashboard..
# WARNING: the number of idxs (=1729) > max_idxs_in_dropdown(=1000). However with your installed version of dash(2.14.0) dropdown search may not work smoothly. You can downgrade to `pip install dash==2.6.2` which should work better for now...
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# For this type of model and model_output interactions don't work, so setting shap_interaction=False...
# The explainer object has no decision_trees property. so setting decision_trees=False...
# Generating layout...
# Calculating shap values...
#   0%|          | 0/1729 [00:00<?, ?it/s]
# Calculating predictions...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb Cell 40 line 3
#       <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y155sZmlsZQ%3D%3D?line=0'>1</a> from explainerdashboard import ExplainerDashboard
# ----> <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y155sZmlsZQ%3D%3D?line=2'>3</a> ExplainerDashboard(explainer).run()
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/explainerdashboard/dashboards.py:803, in ExplainerDashboard.__init__(self, explainer, tabs, title, name, description, simple, hide_header, header_hide_title, header_hide_selector, header_hide_download, hide_poweredby, block_selector_callbacks, pos_label, fluid, mode, width, height, bootstrap, external_stylesheets, server, url_base_pathname, routes_pathname_prefix, requests_pathname_prefix, responsive, logins, port, importances, model_summary, contributions, whatif, shap_dependence, shap_interaction, decision_trees, **kwargs)
#     801 if isinstance(tabs, list):
#     802     tabs = [self._convert_str_tabs(tab) for tab in tabs]
# --> 803     self.explainer_layout = ExplainerTabsLayout(
#     804         explainer,
#     805         tabs,
#     806         title,
#     807         description=self.description,
#     808         **update_kwargs(
#     809             kwargs,
#     810             header_hide_title=self.header_hide_title,
#     811             header_hide_selector=self.header_hide_selector,
#     812             header_hide_download=self.header_hide_download,
#     813             hide_poweredby=self.hide_poweredby,
#     814             block_selector_callbacks=self.block_selector_callbacks,
#     815             pos_label=self.pos_label,
#     816             fluid=fluid,
#     817         ),
#     818     )
#     819 else:
#     820     tabs = self._convert_str_tabs(tabs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/explainerdashboard/dashboards.py:119, in ExplainerTabsLayout.__init__(self, explainer, tabs, title, name, description, header_hide_title, header_hide_selector, header_hide_download, hide_poweredby, block_selector_callbacks, pos_label, fluid, **kwargs)
#     116 self.fluid = fluid
#     118 self.selector = PosLabelSelector(explainer, name="0", pos_label=pos_label)
# --> 119 self.tabs = [
#     120     instantiate_component(tab, explainer, name=str(i + 1), **kwargs)
#     121     for i, tab in enumerate(tabs)
#     122 ]
#     123 assert (
#     124     len(self.tabs) > 0
#     125 ), "When passing a list to tabs, need to pass at least one valid tab!"
#     127 self.register_components(*self.tabs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/explainerdashboard/dashboards.py:120, in <listcomp>(.0)
#     116 self.fluid = fluid
#     118 self.selector = PosLabelSelector(explainer, name="0", pos_label=pos_label)
#     119 self.tabs = [
# --> 120     instantiate_component(tab, explainer, name=str(i + 1), **kwargs)
#     121     for i, tab in enumerate(tabs)
#     122 ]
#     123 assert (
#     124     len(self.tabs) > 0
#     125 ), "When passing a list to tabs, need to pass at least one valid tab!"
#     127 self.register_components(*self.tabs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/explainerdashboard/dashboard_methods.py:890, in instantiate_component(component, explainer, name, **kwargs)
#     884     kwargs = {
#     885         k: v
#     886         for k, v in kwargs.items()
#     887         if k in init_argspec.args + init_argspec.kwonlyargs
#     888     }
#     889 if "name" in init_argspec.args + init_argspec.kwonlyargs:
# --> 890     component = component(explainer, name=name, **kwargs)
#     891 else:
#     892     print(
#     893         f"ExplainerComponent {component} does not accept a name parameter, "
#     894         f"so cannot assign name='{name}': "
#    (...)
#     899         "cluster will generate its own random uuid name!"
#     900     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/explainerdashboard/dashboard_components/composites.py:535, in IndividualPredictionsComposite.__init__(self, explainer, title, name, hide_predindexselector, hide_predictionsummary, hide_contributiongraph, hide_pdp, hide_contributiontable, hide_title, hide_selector, index_check, **kwargs)
#     531     self.summary = ClassifierPredictionSummaryComponent(
#     532         explainer, hide_selector=hide_selector, **kwargs
#     533     )
#     534 elif self.explainer.is_regression:
# --> 535     self.index = RegressionRandomIndexComponent(
#     536         explainer, hide_selector=hide_selector, **kwargs
#     537     )
#     538     self.summary = RegressionPredictionSummaryComponent(
#     539         explainer, hide_selector=hide_selector, **kwargs
#     540     )
#     542 self.contributions = ShapContributionsGraphComponent(
#     543     explainer, hide_selector=hide_selector, **kwargs
#     544 )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/explainerdashboard/dashboard_components/regression_components.py:125, in RegressionRandomIndexComponent.__init__(self, explainer, title, name, subtitle, hide_title, hide_subtitle, hide_index, hide_pred_slider, hide_residual_slider, hide_pred_or_y, hide_abs_residuals, hide_button, index_dropdown, index, pred_slider, y_slider, residual_slider, abs_residual_slider, pred_or_y, abs_residuals, round, description, **kwargs)
#     121     self.abs_residual_slider = [0.0, 1.0]
#     123 if self.pred_slider is None:
#     124     self.pred_slider = [
# --> 125         float(self.explainer.preds.min()),
#     126         float(self.explainer.preds.max()),
#     127     ]
#     129 if not self.explainer.y_missing:
#     130     if self.y_slider is None:
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/explainerdashboard/explainers.py:975, in BaseExplainer.preds(self)
#     970         self._preds = (
#     971             self.model.predict(self.X.values).squeeze().astype(self.precision)
#     972         )
#     973     else:  # Pipelines.predict need pd.DataFrame:
#     974         self._preds = (
# --> 975             self.model.predict(self.X).squeeze().astype(self.precision)
#     976         )
#     978 return self._preds
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:317, in Pipeline.predict(self, X, **predict_params)
#     315 @available_if(_final_estimator_has("predict"))
#     316 def predict(self, X, **predict_params):
# --> 317     X, _ = self._memory_full_transform(self, X, None, with_final=False)
#     319     y = self.steps[-1][-1].predict(X, **predict_params)
#     320     y = self.inverse_transform(y)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/joblib/memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:108, in _full_transform(pipeline, X, y, **kwargs)
#     106 def _full_transform(pipeline: "Pipeline", X, y, **kwargs):
#     107     for _, _, transformer in pipeline._iter(**kwargs):
# --> 108         X, y = pipeline._memory_transform(transformer, X, y)
#     109     return X, y
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/joblib/memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:77, in _transform_one(transformer, X, y)
#      75 if "y" in signature(transformer.transform).parameters:
#      76     args.append(y)
# ---> 77 output = transformer.transform(*args)
#      79 if isinstance(output, tuple):
#      80     X, y = output[0], output[1]
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/preprocess/transformers.py:255, in TransformerWrapper.transform(self, X, y)
#     252     elif "X" not in transform_params:
#     253         return X, y
# --> 255 output = self.transformer.transform(*args)
#     257 # Transform can return X, y or both
#     258 if isinstance(output, tuple):
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/preprocess/transformers.py:304, in ExtractDateTimeFeatures.transform(self, X, y)
#     302 for col in X:
#     303     if not X[col].dtype.name.startswith("datetime"):
# --> 304         raise TypeError(f"Column {col} has no dtype datetime64!")
#     306     for fx in self.features:
#     307         values = getattr(X[col].dt, fx)
#
# TypeError: Column time has no dtype datetime64!

# %%
best_models_dict
# Out:
# {'oslo': Pipeline(memory=Memory(location=None),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(include=['time'],
#                                      transformer=ExtractDateTimeFeatures())),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['temperature', 'day_sin',
#                                               'day_cos', 'week_sin', 'week_cos',
#                                               'year_sin', 'year_cos',
#                                               'consumption_last_week'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('actual_estimator',
#                   GradientBoostingRegressor(random_state=123))]),
#  'trondheim': Pipeline(memory=Memory(location=None),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(include=['time'],
#                                      transformer=ExtractDateTimeFeatures())),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['temperature', 'day_sin',
#                                               'day_cos', 'week_sin', 'week_cos',
#                                               'year_sin', 'year_cos',
#                                               'consumption_last_week'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('actual_estimator',
#                   LGBMRegressor(n_jobs=-1, random_state=123))]),
#  'tromsø': Pipeline(memory=Memory(location=None),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(include=['time'],
#                                      transformer=ExtractDateTimeFeatures())),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['temperature', 'day_sin',
#                                               'day_cos', 'week_sin', 'week_cos',
#                                               'year_sin', 'year_cos',
#                                               'consumption_last_week'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('actual_estimator',
#                   GradientBoostingRegressor(random_state=123))]),
#  'stavanger': Pipeline(memory=Memory(location=None),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(include=['time'],
#                                      transformer=ExtractDateTimeFeatures())),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['temperature', 'day_sin',
#                                               'day_cos', 'week_sin', 'week_cos',
#                                               'year_sin', 'year_cos',
#                                               'consumption_last_week'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('actual_estimator',
#                   GradientBoostingRegressor(random_state=123))]),
#  'bergen': Pipeline(memory=Memory(location=None),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(include=['time'],
#                                      transformer=ExtractDateTimeFeatures())),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['temperature', 'day_sin',
#                                               'day_cos', 'week_sin', 'week_cos',
#                                               'year_sin', 'year_cos',
#                                               'consumption_last_week'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('actual_estimator',
#                   GradientBoostingRegressor(random_state=123))])}

# %%
model_stavanger = best_models_dict["oslo"]
model_stavanger
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('date_feature_extractor',
#                  TransformerWrapper(include=['time'],
#                                     transformer=ExtractDateTimeFeatures())),
#                 ('numerical_imputer',
#                  TransformerWrapper(include=['temperature', 'day_sin',
#                                              'day_cos', 'week_sin', 'week_cos',
#                                              'year_sin', 'year_cos',
#                                              'consumption_last_week'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('actual_estimator',
#                  GradientBoostingRegressor(random_state=123))])

# %%
print(model_stavanger.named_steps)
# Out:
# {'date_feature_extractor': TransformerWrapper(include=['time'], transformer=ExtractDateTimeFeatures()), 'numerical_imputer': TransformerWrapper(include=['temperature', 'day_sin', 'day_cos', 'week_sin',
#                             'week_cos', 'year_sin', 'year_cos',
#                             'consumption_last_week'],
#                    transformer=SimpleImputer()), 'categorical_imputer': TransformerWrapper(include=[],
#                    transformer=SimpleImputer(strategy='most_frequent')), 'actual_estimator': GradientBoostingRegressor(random_state=123)}

# %%
model = model_stavanger.named_steps['actual_estimator']

# %%
interpret_model(model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y152sZmlsZQ%3D%3D?line=0'>1</a> interpret_model(model)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/regression/functional.py:1824, in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1727 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1728 def interpret_model(
#    1729     estimator,
#    (...)
#    1737     **kwargs,
#    1738 ):
#    1739     """
#    1740     This function takes a trained model object and returns an interpretation plot
#    1741     based on the test / hold-out set.
#    (...)
#    1821
#    1822     """
# -> 1824     return _CURRENT_EXPERIMENT.interpret_model(
#    1825         estimator=estimator,
#    1826         plot=plot,
#    1827         feature=feature,
#    1828         observation=observation,
#    1829         use_train_data=use_train_data,
#    1830         X_new_sample=X_new_sample,
#    1831         y_new_sample=y_new_sample,
#    1832         save=save,
#    1833         **kwargs,
#    1834     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/regression/oop.py:2122, in RegressionExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2025 def interpret_model(
#    2026     self,
#    2027     estimator,
#    (...)
#    2035     **kwargs,
#    2036 ):
#    2037     """
#    2038     This function takes a trained model object and returns an interpretation plot
#    2039     based on the test / hold-out set.
#    (...)
#    2119
#    2120     """
# -> 2122     return super().interpret_model(
#    2123         estimator=estimator,
#    2124         plot=plot,
#    2125         feature=feature,
#    2126         observation=observation,
#    2127         use_train_data=use_train_data,
#    2128         X_new_sample=X_new_sample,
#    2129         y_new_sample=y_new_sample,
#    2130         save=save,
#    2131         **kwargs,
#    2132     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:4068, in _SupervisedExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4063 shap_models_ids = set(shap_models.keys())
#    4065 if plot in ["summary", "correlation", "reason"] and (
#    4066     model_id not in shap_models_ids
#    4067 ):
# -> 4068     raise TypeError(
#    4069         f"This function only supports tree based models for binary classification: {', '.join(shap_models_ids)}."
#    4070     )
#    4072 # plot type
#    4073 allowed_types = ["summary", "correlation", "reason", "pdp", "msa", "pfi"]
#
# TypeError: This function only supports tree based models for binary classification: rf, et, lightgbm, dt.

# %%
plot_model(model_stavanger, plot="feature")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y151sZmlsZQ%3D%3D?line=0'>1</a> plot_model(model_stavanger, plot="feature")
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/regression/functional.py:1646, in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1546 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1547 def plot_model(
#    1548     estimator,
#    (...)
#    1557     display_format: Optional[str] = None,
#    1558 ) -> Optional[str]:
#    1559     """
#    1560     This function analyzes the performance of a trained model on holdout set.
#    1561     It may require re-training the model in certain cases.
#    (...)
#    1643
#    1644     """
# -> 1646     return _CURRENT_EXPERIMENT.plot_model(
#    1647         estimator=estimator,
#    1648         plot=plot,
#    1649         scale=scale,
#    1650         save=save,
#    1651         fold=fold,
#    1652         fit_kwargs=fit_kwargs,
#    1653         plot_kwargs=plot_kwargs,
#    1654         groups=groups,
#    1655         verbose=verbose,
#    1656         display_format=display_format,
#    1657     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/regression/oop.py:1946, in RegressionExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1846 def plot_model(
#    1847     self,
#    1848     estimator,
#    (...)
#    1857     display_format: Optional[str] = None,
#    1858 ) -> Optional[str]:
#    1859     """
#    1860     This function analyzes the performance of a trained model on holdout set.
#    1861     It may require re-training the model in certain cases.
#    (...)
#    1943
#    1944     """
# -> 1946     return super().plot_model(
#    1947         estimator=estimator,
#    1948         plot=plot,
#    1949         scale=scale,
#    1950         save=save,
#    1951         fold=fold,
#    1952         fit_kwargs=fit_kwargs,
#    1953         plot_kwargs=plot_kwargs,
#    1954         groups=groups,
#    1955         verbose=verbose,
#    1956         display_format=display_format,
#    1957     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:2045, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, verbose, display_format)
#    1933 def plot_model(
#    1934     self,
#    1935     estimator,
#    (...)
#    1946     display_format: Optional[str] = None,
#    1947 ) -> Optional[str]:
#    1948     """
#    1949     This function takes a trained model object and returns a plot based on the
#    1950     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2043
#    2044     """
# -> 2045     return self._plot_model(
#    2046         estimator=estimator,
#    2047         plot=plot,
#    2048         scale=scale,
#    2049         save=save,
#    2050         fold=fold,
#    2051         fit_kwargs=fit_kwargs,
#    2052         plot_kwargs=plot_kwargs,
#    2053         groups=groups,
#    2054         feature_name=feature_name,
#    2055         label=label,
#    2056         verbose=verbose,
#    2057         display_format=display_format,
#    2058     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:1913, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, verbose, system, display, display_format)
#    1911 # execute the plot method
#    1912 with redirect_output(self.logger):
# -> 1913     ret = locals()[plot]()
#    1914 if ret:
#    1915     plot_filename = ret
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:1810, in _TabularExperiment._plot_model.<locals>.feature()
#    1809 def feature():
# -> 1810     return _feature(10)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:1833, in _TabularExperiment._plot_model.<locals>._feature(n)
#    1829     self.logger.warning(
#    1830         "No coef_ found. Trying feature_importances_"
#    1831     )
#    1832     variables = abs(temp_model.feature_importances_)
# -> 1833 coef_df = pd.DataFrame(
#    1834     {
#    1835         "Variable": self.X_train_transformed.columns,
#    1836         "Value": variables,
#    1837     }
#    1838 )
#    1839 sorted_df = (
#    1840     coef_df.sort_values(by="Value", ascending=False)
#    1841     .head(n)
#    1842     .sort_values(by="Value")
#    1843 )
#    1844 my_range = range(1, len(sorted_df.index) + 1)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     730     mgr = self._init_mgr(
#     731         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     732     )
#     734 elif isinstance(data, dict):
#     735     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 736     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     737 elif isinstance(data, ma.MaskedArray):
#     738     from numpy.ma import mrecords
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
evaluate_model(best_models_dict["trondheim"])
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
stavanger_test_wo_lastweek.head()
# Out:
#                     time  consumption  temperature       day_sin   day_cos  \
# 6912 2023-01-20 21:00:00     7.201020         -5.6 -8.660254e-01  0.500000
# 6913 2023-01-20 22:00:00     7.150055         -5.4 -7.071068e-01  0.707107
# 6914 2023-01-20 23:00:00     6.976293         -5.1 -5.000000e-01  0.866025
# 6915 2023-01-21 00:00:00     6.884066         -5.1 -2.588190e-01  0.965926
# 6916 2023-01-21 01:00:00     6.793396         -4.8 -1.263327e-11  1.000000
#
#       week_sin  week_cos  year_sin  year_cos
# 6912  0.997204 -0.074730  0.336997  0.941506
# 6913  0.993712 -0.111964  0.337672  0.941264
# 6914  0.988831 -0.149042  0.338347  0.941022
# 6915  0.982566 -0.185912  0.339021  0.940779
# 6916  0.974928 -0.222521  0.339695  0.940536

# %%
import shap
explainer = shap.TreeExplainer(model)

stavanger_train_shap =stavanger_train.drop(columns="time")
shap_values = explainer.shap_values(stavanger_train_shap)
# Out:
# ---------------------------------------------------------------------------
# ExplainerError                            Traceback (most recent call last)
# /Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb Cell 39 line 5
#       <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y144sZmlsZQ%3D%3D?line=1'>2</a> explainer = shap.TreeExplainer(model)
#       <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y144sZmlsZQ%3D%3D?line=3'>4</a> stavanger_train_shap =stavanger_train.drop(columns="time")
# ----> <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y144sZmlsZQ%3D%3D?line=4'>5</a> shap_values = explainer.shap_values(stavanger_train_shap)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/shap/explainers/_tree.py:446, in TreeExplainer.shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     444 out = self._get_shap_output(phi, flat_output)
#     445 if check_additivity and self.model.model_output == "raw":
# --> 446     self.assert_additivity(out, self.model.predict(X))
#     448 return out
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/shap/explainers/_tree.py:579, in TreeExplainer.assert_additivity(self, phi, model_output)
#     577         check_sum(self.expected_value[i] + phi[i].sum(-1), model_output[:,i])
#     578 else:
# --> 579     check_sum(self.expected_value + phi.sum(-1), model_output)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/shap/explainers/_tree.py:573, in TreeExplainer.assert_additivity.<locals>.check_sum(sum_val, model_output)
#     569     err_msg += " Consider retrying with the feature_perturbation='interventional' option."
#     570 err_msg += " This check failed because for one of the samples the sum of the SHAP values" \
#     571            " was {:f}, while the model output was {:f}. If this difference is acceptable" \
#     572            " you can set check_additivity=False to disable this check.".format(sum_val[ind], model_output[ind])
# --> 573 raise ExplainerError(err_msg)
#
# ExplainerError: Additivity check failed in TreeExplainer! Please ensure the data matrix you passed to the explainer is the same shape that the model was trained on. If your data shape is correct then please report this on GitHub. Consider retrying with the feature_perturbation='interventional' option. This check failed because for one of the samples the sum of the SHAP values was 4.660266, while the model output was 7.589631. If this difference is acceptable you can set check_additivity=False to disable this check.

# %%
train_pipe = best_oslo[:-1].transform(best_oslo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb Cell 36 line 1
# ----> <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y143sZmlsZQ%3D%3D?line=0'>1</a> train_pipe = best_oslo[:-1].transform(best_oslo)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:278, in Pipeline.transform(self, X, y, filter_train_only)
#     277 def transform(self, X=None, y=None, filter_train_only=True):
# --> 278     X, y = self._memory_full_transform(
#     279         self,
#     280         X,
#     281         y,
#     282         with_final=hasattr(self._final_estimator, "transform"),
#     283         filter_train_only=filter_train_only,
#     284     )
#     286     return variable_return(X, y)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/joblib/memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:108, in _full_transform(pipeline, X, y, **kwargs)
#     106 def _full_transform(pipeline: "Pipeline", X, y, **kwargs):
#     107     for _, _, transformer in pipeline._iter(**kwargs):
# --> 108         X, y = pipeline._memory_transform(transformer, X, y)
#     109     return X, y
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/joblib/memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pipeline.py:77, in _transform_one(transformer, X, y)
#      75 if "y" in signature(transformer.transform).parameters:
#      76     args.append(y)
# ---> 77 output = transformer.transform(*args)
#      79 if isinstance(output, tuple):
#      80     X, y = output[0], output[1]
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/preprocess/transformers.py:233, in TransformerWrapper.transform(self, X, y)
#     232 def transform(self, X=None, y=None):
# --> 233     X = to_df(X, index=getattr(y, "index", None))
#     234     y = to_series(y, index=getattr(X, "index", None), name=self.target_name_)
#     236     args = []
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/utils/generic.py:97, in to_df(data, index, columns, dtypes)
#      94 if not isinstance(data, pd.DataFrame):
#      95     # Assign default column names (dict already has column names)
#      96     if not isinstance(data, dict) and columns is None:
# ---> 97         columns = [f"feature_{str(i)}" for i in range(1, n_cols(data) + 1)]
#      99     # Create dataframe from sparse matrix or directly from data
#     100     if sparse.issparse(data):
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/utils/generic.py:91, in to_df.<locals>.<lambda>(data)
#      66 """Convert a dataset to pd.Dataframe.
#      67
#      68 Parameters
#    (...)
#      88
#      89 """
#      90 # Get number of columns (list/tuple have no shape and sp.matrix has no index)
# ---> 91 n_cols = lambda data: data.shape[1] if hasattr(data, "shape") else len(data[0])
#      93 if data is not None:
#      94     if not isinstance(data, pd.DataFrame):
#      95         # Assign default column names (dict already has column names)
#
# TypeError: object of type 'TransformerWrapper' has no len()

# %%
plot_model(best_oslo, plot = 'feature_all')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb Cell 35 line 1
# ----> <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y136sZmlsZQ%3D%3D?line=0'>1</a> plot_model(best_oslo, plot = 'feature_all')
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/regression/functional.py:1646, in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1546 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1547 def plot_model(
#    1548     estimator,
#    (...)
#    1557     display_format: Optional[str] = None,
#    1558 ) -> Optional[str]:
#    1559     """
#    1560     This function analyzes the performance of a trained model on holdout set.
#    1561     It may require re-training the model in certain cases.
#    (...)
#    1643
#    1644     """
# -> 1646     return _CURRENT_EXPERIMENT.plot_model(
#    1647         estimator=estimator,
#    1648         plot=plot,
#    1649         scale=scale,
#    1650         save=save,
#    1651         fold=fold,
#    1652         fit_kwargs=fit_kwargs,
#    1653         plot_kwargs=plot_kwargs,
#    1654         groups=groups,
#    1655         verbose=verbose,
#    1656         display_format=display_format,
#    1657     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/regression/oop.py:1946, in RegressionExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1846 def plot_model(
#    1847     self,
#    1848     estimator,
#    (...)
#    1857     display_format: Optional[str] = None,
#    1858 ) -> Optional[str]:
#    1859     """
#    1860     This function analyzes the performance of a trained model on holdout set.
#    1861     It may require re-training the model in certain cases.
#    (...)
#    1943
#    1944     """
# -> 1946     return super().plot_model(
#    1947         estimator=estimator,
#    1948         plot=plot,
#    1949         scale=scale,
#    1950         save=save,
#    1951         fold=fold,
#    1952         fit_kwargs=fit_kwargs,
#    1953         plot_kwargs=plot_kwargs,
#    1954         groups=groups,
#    1955         verbose=verbose,
#    1956         display_format=display_format,
#    1957     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:2045, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, verbose, display_format)
#    1933 def plot_model(
#    1934     self,
#    1935     estimator,
#    (...)
#    1946     display_format: Optional[str] = None,
#    1947 ) -> Optional[str]:
#    1948     """
#    1949     This function takes a trained model object and returns a plot based on the
#    1950     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2043
#    2044     """
# -> 2045     return self._plot_model(
#    2046         estimator=estimator,
#    2047         plot=plot,
#    2048         scale=scale,
#    2049         save=save,
#    2050         fold=fold,
#    2051         fit_kwargs=fit_kwargs,
#    2052         plot_kwargs=plot_kwargs,
#    2053         groups=groups,
#    2054         feature_name=feature_name,
#    2055         label=label,
#    2056         verbose=verbose,
#    2057         display_format=display_format,
#    2058     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:1913, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, verbose, system, display, display_format)
#    1911 # execute the plot method
#    1912 with redirect_output(self.logger):
# -> 1913     ret = locals()[plot]()
#    1914 if ret:
#    1915     plot_filename = ret
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:1813, in _TabularExperiment._plot_model.<locals>.feature_all()
#    1812 def feature_all():
# -> 1813     return _feature(len(self.X_train_transformed.columns))
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:1833, in _TabularExperiment._plot_model.<locals>._feature(n)
#    1829     self.logger.warning(
#    1830         "No coef_ found. Trying feature_importances_"
#    1831     )
#    1832     variables = abs(temp_model.feature_importances_)
# -> 1833 coef_df = pd.DataFrame(
#    1834     {
#    1835         "Variable": self.X_train_transformed.columns,
#    1836         "Value": variables,
#    1837     }
#    1838 )
#    1839 sorted_df = (
#    1840     coef_df.sort_values(by="Value", ascending=False)
#    1841     .head(n)
#    1842     .sort_values(by="Value")
#    1843 )
#    1844 my_range = range(1, len(sorted_df.index) + 1)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     730     mgr = self._init_mgr(
#     731         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     732     )
#     734 elif isinstance(data, dict):
#     735     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 736     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     737 elif isinstance(data, ma.MaskedArray):
#     738     from numpy.ma import mrecords
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
# !pip install explainerdashboard
# Out:
# Requirement already satisfied: explainerdashboard in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (0.4.3)
# Requirement already satisfied: click in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (8.1.7)
# Requirement already satisfied: dash-auth in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-bootstrap-components>=1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (1.5.0)
# Requirement already satisfied: dash>=2.10.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (2.14.0)
# Requirement already satisfied: dtreeviz>=2.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (2.2.2)
# Requirement already satisfied: flask-simplelogin in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (0.1.2)
# Requirement already satisfied: Flask-WTF>=1.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (1.2.1)
# Requirement already satisfied: graphviz>=0.18.2 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (0.20.1)
# Requirement already satisfied: joblib in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (1.3.2)
# Requirement already satisfied: jupyter-dash>=0.4.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (0.4.2)
# Requirement already satisfied: numpy<=1.24.4 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (1.23.5)
# Requirement already satisfied: oyaml in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (1.0)
# Requirement already satisfied: pandas>=1.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (1.2.2)
# Requirement already satisfied: shap>=0.42.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (0.43.0)
# Requirement already satisfied: waitress in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from explainerdashboard) (2.1.2)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (2.2.5)
# Requirement already satisfied: Werkzeug<2.3.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (5.17.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (4.8.0)
# Requirement already satisfied: requests in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (2.31.0)
# Requirement already satisfied: retrying in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (1.3.4)
# Requirement already satisfied: ansi2html in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (1.8.0)
# Requirement already satisfied: nest-asyncio in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (1.5.8)
# Requirement already satisfied: setuptools in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (68.0.0)
# Requirement already satisfied: importlib-metadata in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dash>=2.10.1->explainerdashboard) (6.8.0)
# Requirement already satisfied: matplotlib in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dtreeviz>=2.1->explainerdashboard) (3.7.2)
# Requirement already satisfied: colour in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dtreeviz>=2.1->explainerdashboard) (0.1.5)
# Requirement already satisfied: pytest in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from dtreeviz>=2.1->explainerdashboard) (7.4.3)
# Requirement already satisfied: itsdangerous in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from Flask-WTF>=1.1->explainerdashboard) (2.1.2)
# Requirement already satisfied: wtforms in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from Flask-WTF>=1.1->explainerdashboard) (3.1.1)
# Requirement already satisfied: ipython in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (8.16.1)
# Requirement already satisfied: ipykernel in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from jupyter-dash>=0.4.1->explainerdashboard) (6.25.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from pandas>=1.1->explainerdashboard) (2023.3.post1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from scikit-learn>=1.1->explainerdashboard) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from scikit-learn>=1.1->explainerdashboard) (3.2.0)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from shap>=0.42.1->explainerdashboard) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from shap>=0.42.1->explainerdashboard) (23.2)
# Requirement already satisfied: slicer==0.0.7 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from shap>=0.42.1->explainerdashboard) (0.0.7)
# Requirement already satisfied: numba in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from shap>=0.42.1->explainerdashboard) (0.58.1)
# Requirement already satisfied: cloudpickle in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from shap>=0.42.1->explainerdashboard) (2.2.1)
# Requirement already satisfied: pyyaml in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from oyaml->explainerdashboard) (6.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.10.1->explainerdashboard) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from plotly>=5.0.0->dash>=2.10.1->explainerdashboard) (8.2.3)
# Requirement already satisfied: six>=1.5 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.1->explainerdashboard) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from Werkzeug<2.3.0->dash>=2.10.1->explainerdashboard) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from importlib-metadata->dash>=2.10.1->explainerdashboard) (3.17.0)
# Requirement already satisfied: appnope in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (8.4.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (0.1.6)
# Requirement already satisfied: psutil in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (5.11.2)
# Requirement already satisfied: backcall in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.0)
# Requirement already satisfied: decorator in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.19.1)
# Requirement already satisfied: pickleshare in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.16.1)
# Requirement already satisfied: stack-data in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.6.2)
# Requirement already satisfied: exceptiongroup in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.1->explainerdashboard) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from matplotlib->dtreeviz>=2.1->explainerdashboard) (3.0.9)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from numba->shap>=0.42.1->explainerdashboard) (0.41.1)
# Requirement already satisfied: iniconfig in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (1.3.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from pytest->dtreeviz>=2.1->explainerdashboard) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from requests->dash>=2.10.1->explainerdashboard) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from requests->dash>=2.10.1->explainerdashboard) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from requests->dash>=2.10.1->explainerdashboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from requests->dash>=2.10.1->explainerdashboard) (2023.7.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash>=0.4.1->explainerdashboard) (3.11.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from pexpect>4.3->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (2.4.0)
# Requirement already satisfied: pure-eval in /Users/nicolayhagen/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash>=0.4.1->explainerdashboard) (0.2.2)

# %%
model = best_models_dict["oslo"]
dashboard(model) # https://www.youtube.com/watch?v=FZ5-GtdYez0
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb Cell 36 line 2
#       <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y126sZmlsZQ%3D%3D?line=0'>1</a> model = best_models_dict["oslo"]
# ----> <a href='vscode-notebook-cell:/Users/nicolayhagen/TDT-4173-2023-task-1-master/aneo/final_model-experiment1.ipynb#Y126sZmlsZQ%3D%3D?line=1'>2</a> dashboard(model) # https://www.youtube.com/watch?v=FZ5-GtdYez0
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/regression/functional.py:2711, in dashboard(estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs)
#    2657 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    2658 def dashboard(
#    2659     estimator,
#    (...)
#    2663     **kwargs,
#    2664 ):
#    2665     """
#    2666     This function generates the interactive dashboard for a trained model. The
#    2667     dashboard is implemented using ExplainerDashboard (explainerdashboard.readthedocs.io)
#    (...)
#    2708         ExplainerDashboard
#    2709     """
# -> 2711     return _CURRENT_EXPERIMENT.dashboard(
#    2712         estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs
#    2713     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/regression/oop.py:2773, in RegressionExperiment.dashboard(self, estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs)
#    2726 """
#    2727 This function generates the interactive dashboard for a trained model. The
#    2728 dashboard is implemented using ExplainerDashboard (explainerdashboard.readthedocs.io)
#    (...)
#    2769     ExplainerDashboard
#    2770 """
#    2772 # soft dependencies check
# -> 2773 super().dashboard(
#    2774     estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs
#    2775 )
#    2777 dashboard_kwargs = dashboard_kwargs or {}
#    2778 run_kwargs = run_kwargs or {}
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:5517, in _SupervisedExperiment.dashboard(self, estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs)
#    5463 def dashboard(
#    5464     self,
#    5465     estimator,
#    (...)
#    5469     **kwargs,
#    5470 ):
#    5471     """
#    5472     This function generates the interactive dashboard for a trained model. The
#    5473     dashboard is implemented using ExplainerDashboard (explainerdashboard.readthedocs.io)
#    (...)
#    5514         None
#    5515     """
# -> 5517     _check_soft_dependencies(
#    5518         "explainerdashboard", extra="analysis", severity="error"
#    5519     )
#
# File ~/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages/pycaret/utils/_dependencies.py:152, in _check_soft_dependencies(package, severity, extra, install_name)
#     150 if severity == "error":
#     151     logger.exception(f"{msg}")
# --> 152     raise ModuleNotFoundError(msg)
#     153 elif severity == "warning":
#     154     logger.warning(f"{msg}")
#
# ModuleNotFoundError:
# 'explainerdashboard' is a soft dependency and not included in the pycaret installation. Please run: `pip install explainerdashboard` to install.
# Alternately, you can install this by running `pip install pycaret[analysis]`

# %% [markdown]
# # GRAVEYARD #

# %%
# An interesting view is looking at the Actual Values and Predicted Values (Label) in a histogram over the entire dataset. This shows the distribution between the values. We can see how the Predicted Values seem to peak in a more distributed manner and skew to the left. 
plt.figure(figsize=(15,5))
sns.set_style("whitegrid")
sns.distplot(predict_unseen["consumption"],
                kde=False,
                color="#c6690c")
sns.distplot(predict_unseen["prediction_label"],
                kde=False,
                color="#664697")
plt.title("Distribution between Actual Value and Predicted Value")
plt.ylabel("Count")
plt.xlabel("Consumption")
#plt.xlim((74,101))
plt.legend(('Actual Value', 'Predicted Value (Label)'), ncol=2, loc='upper left', fontsize=12)

# %%
# We can plot the Predicted Value (Label) vs Actual Value 
sns.regplot(x="consumption", y="prediction_label", data=predict_unseen, scatter_kws ={'s':50}, line_kws={"color": "#664697"}, color="#c6690c")
plt.title("Linear Relationship between Actual Consumption and Predicted Consumption (Label)")
plt.ylabel("Predicted Consumption (Label)")
plt.xlabel("Actual Consumption")
plt.legend(('Actual Consumption vs Predicted Consumption (Label)', 'Best Fit'), ncol=2, loc='upper left', fontsize=12)

# %%
#Train the model on the whole training set
final_model = finalize_model(knn)
predictions = predict_model(final_model, data = pd_data)
predictions.to_csv('pred_final_blender.csv')
predictions.describe()
# Out:
# <style type="text/css">
# </style>
# <table id="T_b46d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b46d7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b46d7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b46d7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b46d7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b46d7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b46d7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b46d7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b46d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b46d7_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_b46d7_row0_col1" class="data row0 col1" >0.2940</td>
#       <td id="T_b46d7_row0_col2" class="data row0 col2" >0.2726</td>
#       <td id="T_b46d7_row0_col3" class="data row0 col3" >0.5221</td>
#       <td id="T_b46d7_row0_col4" class="data row0 col4" >0.9716</td>
#       <td id="T_b46d7_row0_col5" class="data row0 col5" >0.1061</td>
#       <td id="T_b46d7_row0_col6" class="data row0 col6" >0.1081</td>
#     </tr>
#   </tbody>
# </table>
#         temperature   consumption  prediction_label
# count  49494.000000  49494.000000      49494.000000
# mean       6.554018      3.509242          3.498075
# std        7.630100      3.096338          3.007989
# min      -17.299999      0.000000          0.573747
# 25%        1.000000      1.263256          1.318215
# 50%        6.800000      2.376530          2.488980
# 75%       12.100000      5.189000          5.172479
# max       30.500000     18.045012         15.591287

# %%
evaluate_model(final_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# An interesting view is looking at the Actual Values and Predicted Values (Label) in a histogram over the entire dataset. This shows the distribution between the values. We can see how the Predicted Values seem to peak in a more distributed manner and skew to the left. 
plt.figure(figsize=(15,5))
sns.set_style("whitegrid")
sns.distplot(predictions["consumption"],
                kde=False,
                color="#c6690c")
sns.distplot(predictions["prediction_label"],
                kde=False,
                color="#664697")
plt.title("Distribution between Actual Value and Predicted Value")
plt.ylabel("Count")
plt.xlabel("Consumption")
#plt.xlim((74,101))
plt.legend(('Actual Value', 'Predicted Value (Label)'), ncol=2, loc='upper left', fontsize=12)

# %%
save_model(final_model, 'knn_v1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['temperature'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['time', 'location'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['location'],
#                                      transformer=OneHotEncoder(cols=['location'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['time'],
#                                      transformer=TargetEncoder(cols=['time'],
#                                                                handle_missing='return_nan'))),
#                  ('actual_estimator',
#                   KNeighborsRegressor(n_jobs=-1, n_neighbors=50))]),
#  'knn_v1.pkl')

# %%
#Sources
# https://nbviewer.org/github/pycaret/examples/blob/main/Pycaret_2.1_Regression_EmployeePerformance.ipynb
